# %% [markdown]
# # Frame Overlap: Analyzing Neutron Time-of-Flight Data
#
# This tutorial demonstrates how to use the `frame_overlap` Python package to analyze neutron Time-of-Flight (ToF) data. The package provides tools for data preparation, kernel generation, Wiener deconvolution, parameter optimization, and visualization.

# %%
# Installation (uncomment if needed)
# !pip install git+https://github.com/TsvikiHirsh/frame_overlap.git

# %%
from frame_overlap import (
    read_tof_data,
    generate_kernel,
    apply_filter,
    chi2_analysis,
    plot_analysis,
    optimize_parameters
)
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading and Preparing Data

# %%
# Read the ToF data from a CSV file
t_signal, signal, errors, stacks = read_tof_data('iron_powder.csv', threshold=30)

# %% [markdown]
# ## Generating the Kernel

# %%
# Generate a kernel with specified number of pulses and pulse duration
t_kernel, kernel = generate_kernel(n_pulses=5, pulse_duration=200)

# %% [markdown]
# ## Applying Wiener Deconvolution

# %%
# Apply Wiener deconvolution to the signal
observed_poisson, reconstructed = apply_filter(
    signal,
    kernel,
    stats_fraction=0.2,
    noise_power=0.05
)

# %% [markdown]
# ## Analyzing the Results

# %%
# Scale the original signal for comparison
scaled_original = signal * 0.2

# Calculate chi-squared statistics
chi2, chi2_per_dof = chi2_analysis(
    scaled_original,
    reconstructed,
    np.sqrt(observed_poisson)
)

# Plot the analysis results
plot_analysis(
    t_signal,
    signal,
    scaled_original,
    t_kernel,
    kernel,
    observed_poisson,
    reconstructed,
    scaled_original - reconstructed,
    chi2_per_dof
)

# %% [markdown]
# ## Optimizing Parameters

# %%
# Optimize model parameters based on the signal
result = optimize_parameters(t_signal, signal)

# Print the optimization report
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(deconvolution_model)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>14</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>2371</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>3</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.1719e+09</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 494900.376</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 31091.8151</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 31109.1283</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.99544390</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>n_pulses</td><td style='text-align:left'> 5.00001439</td><td style='text-align:left'> 8.6347e-07</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>5</td><td style='text-align:left'> 1.00000000</td><td style='text-align:left'> 20.0000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>noise_power</td><td style='text-align:left'> 0.05000059</td><td style='text-align:left'> 4.6287e-08</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>0.05</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 1.00000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>pulse_duration</td><td style='text-align:left'> 200.000581</td><td style='text-align:left'> 4.4966e-05</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>200</td><td style='text-align:left'> 10.0000000</td><td style='text-align:left'> 1000.00000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>window_size</td><td style='text-align:left'> 5000.00000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>5000</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>stats_fraction</td><td style='text-align:left'> 0.20000000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>0.2</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>noise_power</td><td style='text-align:left'>pulse_duration</td><td style='text-align:right'>-0.3727</td></tr><tr><td style='text-align:left'>n_pulses</td><td style='text-align:left'>noise_power</td><td style='text-align:right'>-0.2887</td></tr><tr><td style='text-align:left'>n_pulses</td><td style='text-align:left'>pulse_duration</td><td style='text-align:right'>-0.2840</td></tr></table>

# %%
result.plot();
